# %%
import os
from IPython.display import clear_output
os.chdir('/content/drive/MyDrive/fieldbooks_antioch/')
# !pwd
#!git init .
# Out:
# /content/drive/MyDrive/fieldbooks_antioch

# %%
# !git branch -m master main

# %%
# !git config --global user.email "jeffblackadar@gmail.com"
# !git config --global user.name "jeffblackadar"

# %%
#https://amitness.com/2020/06/google-colaboratory-tips/
import subprocess
input
print('Enter your pat:')
pat = input()
#command = "git remote add origin https://"+pat+"@github.com/jeffblackadar/fieldbooks_antioch.git"
#subprocess.call(command, shell=True)
command = "git remote set-url origin https://"+pat+"@github.com/jeffblackadar/fieldbooks_antioch.git"
subprocess.call(command, shell=True)
clear_output(wait=False)

# %%
# !git pull origin main
# Out:
# From https://github.com/jeffblackadar/fieldbooks_antioch
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !git add -A

# %%
# !git commit -m "edited for consistency"
# Out:
# [main 0f804c6] edited for consistency
#  4 files changed, 2 insertions(+), 3 deletions(-)
#  rewrite fieldbook_antioch_extract_text.ipynb (97%)
#  copy fieldbook_antioch_extract_text.ipynb => fieldbook_antioch_extract_text_old.ipynb (100%)
#  delete mode 100644 fieldbook_v2_antioch_extract_text.ipynb
#  rewrite git.ipynb (72%)

# %%
# !git push
clear_output(wait=False)

# %%
# !git push --set-upstream origin main
clear_output(wait=False)
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.21 KiB | 206.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/jeffblackadar/fieldbooks_antioch.git
#    efac11d..7a2bc3c  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
print("he")
clear_output(wait=False)
